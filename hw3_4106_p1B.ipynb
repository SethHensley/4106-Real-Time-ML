# %%
#Seth Hensley
#801055921
#Homework 3

import tensorflow as tf
import keras 
import numpy as np 
import matplotlib.pyplot as plt


(xtrain, ytrain), (xtest, ytest)= tf.keras.datasets.cifar10.load_data()

# %%
xtrain=tf.image.resize(xtrain,(64,64))
xtest=tf.image.resize(xtest,(64,64))


xtrain = xtrain/255.0

#ytrain = ytrain/255.0

xtest = xtest/255.0

#ytest = ytest/255.0

plt.imshow(xtrain[42069,:,:],cmap='Greys')

# %%
def vggC():
    model = tf.keras.Sequential([
        tf.keras.Input(shape = (64,64,3)),
        keras.layers.Conv2D(64, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(64, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.MaxPool2D(2, strides = 2),
        
        keras.layers.Conv2D(128, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(128, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.MaxPool2D(2,strides = 2),
        
        keras.layers.Conv2D(256, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(256, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(256, 1, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.MaxPool2D(2,strides = 2),
        
        keras.layers.Conv2D(512, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(512, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(512, 1, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.MaxPool2D(2,strides = 2),
        
        keras.layers.Conv2D(512, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(512, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(512, 1, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.MaxPool2D(2,strides = 2),
        
        keras.layers.Flatten(),
        keras.layers.Dense(4096),
        keras.layers.Activation("relu"),
        keras.layers.Dense(4096),
        keras.layers.Activation("relu"),
        keras.layers.Dense(1000),
        keras.layers.Softmax()
    ])
    
    
    return model

def vggD():
    model = tf.keras.Sequential([
        tf.keras.Input(shape = (64,64,3)),
        keras.layers.Conv2D(64, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(64, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.MaxPool2D(2, strides = 2),
        
        keras.layers.Conv2D(128, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(128, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.MaxPool2D(2,strides = 2),
        
        keras.layers.Conv2D(256, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(256, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(256, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.MaxPool2D(2,strides = 2),
        
        keras.layers.Conv2D(512, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(512, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(512, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.MaxPool2D(2,strides = 2),
        
        keras.layers.Conv2D(512, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(512, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(512, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.MaxPool2D(2,strides = 2),
        
        keras.layers.Flatten(),
        keras.layers.Dense(4096),
        keras.layers.Activation("relu"),
        keras.layers.Dense(4096),
        keras.layers.Activation("relu"),
        keras.layers.Dense(1000),
        keras.layers.Softmax()
    ])
    
    
    return model


def vggE():
    model = tf.keras.Sequential([
        tf.keras.Input(shape = (64,64,3)),
        keras.layers.Conv2D(64, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(64, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.MaxPool2D(2, strides = 2),
        
        keras.layers.Conv2D(128, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(128, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.MaxPool2D(2,strides = 2),
        
        keras.layers.Conv2D(256, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(256, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(256, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(256, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.MaxPool2D(2,strides = 2),
        
        keras.layers.Conv2D(512, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(512, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(512, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(512, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.MaxPool2D(2,strides = 2),
        
        keras.layers.Conv2D(512, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(512, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(512, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.Conv2D(512, 3, padding = "same"),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("relu"),
        keras.layers.MaxPool2D(2,strides = 2),
        
        keras.layers.Flatten(),
        keras.layers.Dense(4096),
        keras.layers.Activation("relu"),
        keras.layers.Dense(4096),
        keras.layers.Activation("relu"),
        keras.layers.Dense(1000),
        keras.layers.Softmax()
    ])
    
    
    return model

# %%
model2 = vggC()
model3=vggD()
model4=vggE()

# %%
model2.compile(optimizer="adam", loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits= True), metrics=["accuracy"])
model2.summary()

model3.compile(optimizer="adam", loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits= True), metrics=["accuracy"])
model3.summary()

model4.compile(optimizer="adam", loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits= True), metrics=["accuracy"])
model4.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 64)        1792
#
#  batch_normalization (BatchN  (None, 64, 64, 64)       256
#  ormalization)
#
#  activation (Activation)     (None, 64, 64, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 64, 64, 64)        0
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 32, 32, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  activation_3 (Activation)   (None, 32, 32, 128)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 256)       295168
#
#  batch_normalization_4 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 16, 16, 256)       0
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 256)       590080
#
#  batch_normalization_5 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 16, 16, 256)       0
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 256)       65792
#
#  batch_normalization_6 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  activation_6 (Activation)   (None, 16, 16, 256)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 512)         1180160
#
#  batch_normalization_7 (Batc  (None, 8, 8, 512)        2048
#  hNormalization)
#
#  activation_7 (Activation)   (None, 8, 8, 512)         0
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 512)         2359808
#
#  batch_normalization_8 (Batc  (None, 8, 8, 512)        2048
#  hNormalization)
#
#  activation_8 (Activation)   (None, 8, 8, 512)         0
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 512)         262656
#
#  batch_normalization_9 (Batc  (None, 8, 8, 512)        2048
#  hNormalization)
#
#  activation_9 (Activation)   (None, 8, 8, 512)         0
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 512)        0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 4, 4, 512)         2359808
#
#  batch_normalization_10 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_10 (Activation)  (None, 4, 4, 512)         0
#
#  conv2d_11 (Conv2D)          (None, 4, 4, 512)         2359808
#
#  batch_normalization_11 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_11 (Activation)  (None, 4, 4, 512)         0
#
#  conv2d_12 (Conv2D)          (None, 4, 4, 512)         262656
#
#  batch_normalization_12 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_12 (Activation)  (None, 4, 4, 512)         0
#
#  max_pooling2d_4 (MaxPooling  (None, 2, 2, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 4096)              8392704
#
#  activation_13 (Activation)  (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  activation_14 (Activation)  (None, 4096)              0
#
#  dense_2 (Dense)             (None, 1000)              4097000
#
#  softmax (Softmax)           (None, 1000)              0
#
# =================================================================
# Total params: 39,284,008
# Trainable params: 39,275,560
# Non-trainable params: 8,448
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_13 (Conv2D)          (None, 64, 64, 64)        1792
#
#  batch_normalization_13 (Bat  (None, 64, 64, 64)       256
#  chNormalization)
#
#  activation_15 (Activation)  (None, 64, 64, 64)        0
#
#  conv2d_14 (Conv2D)          (None, 64, 64, 64)        36928
#
#  batch_normalization_14 (Bat  (None, 64, 64, 64)       256
#  chNormalization)
#
#  activation_16 (Activation)  (None, 64, 64, 64)        0
#
#  max_pooling2d_5 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_15 (Conv2D)          (None, 32, 32, 128)       73856
#
#  batch_normalization_15 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  activation_17 (Activation)  (None, 32, 32, 128)       0
#
#  conv2d_16 (Conv2D)          (None, 32, 32, 128)       147584
#
#  batch_normalization_16 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  activation_18 (Activation)  (None, 32, 32, 128)       0
#
#  max_pooling2d_6 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  conv2d_17 (Conv2D)          (None, 16, 16, 256)       295168
#
#  batch_normalization_17 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  activation_19 (Activation)  (None, 16, 16, 256)       0
#
#  conv2d_18 (Conv2D)          (None, 16, 16, 256)       590080
#
#  batch_normalization_18 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  activation_20 (Activation)  (None, 16, 16, 256)       0
#
#  conv2d_19 (Conv2D)          (None, 16, 16, 256)       590080
#
#  batch_normalization_19 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  activation_21 (Activation)  (None, 16, 16, 256)       0
#
#  max_pooling2d_7 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  conv2d_20 (Conv2D)          (None, 8, 8, 512)         1180160
#
#  batch_normalization_20 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  activation_22 (Activation)  (None, 8, 8, 512)         0
#
#  conv2d_21 (Conv2D)          (None, 8, 8, 512)         2359808
#
#  batch_normalization_21 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  activation_23 (Activation)  (None, 8, 8, 512)         0
#
#  conv2d_22 (Conv2D)          (None, 8, 8, 512)         2359808
#
#  batch_normalization_22 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  activation_24 (Activation)  (None, 8, 8, 512)         0
#
#  max_pooling2d_8 (MaxPooling  (None, 4, 4, 512)        0
#  2D)
#
#  conv2d_23 (Conv2D)          (None, 4, 4, 512)         2359808
#
#  batch_normalization_23 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_25 (Activation)  (None, 4, 4, 512)         0
#
#  conv2d_24 (Conv2D)          (None, 4, 4, 512)         2359808
#
#  batch_normalization_24 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_26 (Activation)  (None, 4, 4, 512)         0
#
#  conv2d_25 (Conv2D)          (None, 4, 4, 512)         2359808
#
#  batch_normalization_25 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_27 (Activation)  (None, 4, 4, 512)         0
#
#  max_pooling2d_9 (MaxPooling  (None, 2, 2, 512)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_3 (Dense)             (None, 4096)              8392704
#
#  activation_28 (Activation)  (None, 4096)              0
#
#  dense_4 (Dense)             (None, 4096)              16781312
#
#  activation_29 (Activation)  (None, 4096)              0
#
#  dense_5 (Dense)             (None, 1000)              4097000
#
#  softmax_1 (Softmax)         (None, 1000)              0
#
# =================================================================
# Total params: 44,002,600
# Trainable params: 43,994,152
# Non-trainable params: 8,448
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_26 (Conv2D)          (None, 64, 64, 64)        1792
#
#  batch_normalization_26 (Bat  (None, 64, 64, 64)       256
#  chNormalization)
#
#  activation_30 (Activation)  (None, 64, 64, 64)        0
#
#  conv2d_27 (Conv2D)          (None, 64, 64, 64)        36928
#
#  batch_normalization_27 (Bat  (None, 64, 64, 64)       256
#  chNormalization)
#
#  activation_31 (Activation)  (None, 64, 64, 64)        0
#
#  max_pooling2d_10 (MaxPoolin  (None, 32, 32, 64)       0
#  g2D)
#
#  conv2d_28 (Conv2D)          (None, 32, 32, 128)       73856
#
#  batch_normalization_28 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  activation_32 (Activation)  (None, 32, 32, 128)       0
#
#  conv2d_29 (Conv2D)          (None, 32, 32, 128)       147584
#
#  batch_normalization_29 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  activation_33 (Activation)  (None, 32, 32, 128)       0
#
#  max_pooling2d_11 (MaxPoolin  (None, 16, 16, 128)      0
#  g2D)
#
#  conv2d_30 (Conv2D)          (None, 16, 16, 256)       295168
#
#  batch_normalization_30 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  activation_34 (Activation)  (None, 16, 16, 256)       0
#
#  conv2d_31 (Conv2D)          (None, 16, 16, 256)       590080
#
#  batch_normalization_31 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  activation_35 (Activation)  (None, 16, 16, 256)       0
#
#  conv2d_32 (Conv2D)          (None, 16, 16, 256)       590080
#
#  batch_normalization_32 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  activation_36 (Activation)  (None, 16, 16, 256)       0
#
#  conv2d_33 (Conv2D)          (None, 16, 16, 256)       590080
#
#  batch_normalization_33 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  activation_37 (Activation)  (None, 16, 16, 256)       0
#
#  max_pooling2d_12 (MaxPoolin  (None, 8, 8, 256)        0
#  g2D)
#
#  conv2d_34 (Conv2D)          (None, 8, 8, 512)         1180160
#
#  batch_normalization_34 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  activation_38 (Activation)  (None, 8, 8, 512)         0
#
#  conv2d_35 (Conv2D)          (None, 8, 8, 512)         2359808
#
#  batch_normalization_35 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  activation_39 (Activation)  (None, 8, 8, 512)         0
#
#  conv2d_36 (Conv2D)          (None, 8, 8, 512)         2359808
#
#  batch_normalization_36 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  activation_40 (Activation)  (None, 8, 8, 512)         0
#
#  conv2d_37 (Conv2D)          (None, 8, 8, 512)         2359808
#
#  batch_normalization_37 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  activation_41 (Activation)  (None, 8, 8, 512)         0
#
#  max_pooling2d_13 (MaxPoolin  (None, 4, 4, 512)        0
#  g2D)
#
#  conv2d_38 (Conv2D)          (None, 4, 4, 512)         2359808
#
#  batch_normalization_38 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_42 (Activation)  (None, 4, 4, 512)         0
#
#  conv2d_39 (Conv2D)          (None, 4, 4, 512)         2359808
#
#  batch_normalization_39 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_43 (Activation)  (None, 4, 4, 512)         0
#
#  conv2d_40 (Conv2D)          (None, 4, 4, 512)         2359808
#
#  batch_normalization_40 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_44 (Activation)  (None, 4, 4, 512)         0
#
#  conv2d_41 (Conv2D)          (None, 4, 4, 512)         2359808
#
#  batch_normalization_41 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_45 (Activation)  (None, 4, 4, 512)         0
#
#  max_pooling2d_14 (MaxPoolin  (None, 2, 2, 512)        0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dense_6 (Dense)             (None, 4096)              8392704
#
#  activation_46 (Activation)  (None, 4096)              0
#
#  dense_7 (Dense)             (None, 4096)              16781312
#
#  activation_47 (Activation)  (None, 4096)              0
#
#  dense_8 (Dense)             (None, 1000)              4097000
#
#  softmax_2 (Softmax)         (None, 1000)              0
#
# =================================================================
# Total params: 49,317,416
# Trainable params: 49,306,408
# Non-trainable params: 11,008
# _________________________________________________________________

# %%
model2.fit(xtrain,ytrain,validation_data=(xtest,ytest),epochs=10)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.9/dist-packages/keras/backend.py:5585: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1563/1563 [==============================] - 106s 60ms/step - loss: 1.9130 - accuracy: 0.2891 - val_loss: 1.9079 - val_accuracy: 0.3091
# Epoch 2/10
# 1563/1563 [==============================] - 92s 59ms/step - loss: 1.2927 - accuracy: 0.5285 - val_loss: 1.3895 - val_accuracy: 0.5255
# Epoch 3/10
# 1563/1563 [==============================] - 92s 59ms/step - loss: 0.9599 - accuracy: 0.6580 - val_loss: 0.8817 - val_accuracy: 0.6890
# Epoch 4/10
# 1563/1563 [==============================] - 92s 59ms/step - loss: 0.7708 - accuracy: 0.7318 - val_loss: 1.0993 - val_accuracy: 0.6538
# Epoch 5/10
# 1563/1563 [==============================] - 93s 59ms/step - loss: 0.6291 - accuracy: 0.7836 - val_loss: 0.8302 - val_accuracy: 0.7219
# Epoch 6/10
# 1563/1563 [==============================] - 93s 59ms/step - loss: 0.5275 - accuracy: 0.8214 - val_loss: 0.7696 - val_accuracy: 0.7464
# Epoch 7/10
# 1563/1563 [==============================] - 92s 59ms/step - loss: 0.4370 - accuracy: 0.8508 - val_loss: 0.8493 - val_accuracy: 0.7377
# Epoch 8/10
# 1563/1563 [==============================] - 92s 59ms/step - loss: 0.3638 - accuracy: 0.8761 - val_loss: 0.6789 - val_accuracy: 0.7865
# Epoch 9/10
# 1563/1563 [==============================] - 92s 59ms/step - loss: 0.3010 - accuracy: 0.8968 - val_loss: 0.6076 - val_accuracy: 0.8092
# Epoch 10/10
# 1563/1563 [==============================] - 92s 59ms/step - loss: 0.2466 - accuracy: 0.9164 - val_loss: 0.5727 - val_accuracy: 0.8205

# %%
model3.fit(xtrain,ytrain,validation_data=(xtest,ytest),epochs=10)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 118s 70ms/step - loss: 1.9506 - accuracy: 0.2711 - val_loss: 1.6622 - val_accuracy: 0.3661
# Epoch 2/10
# 1563/1563 [==============================] - 105s 67ms/step - loss: 1.3779 - accuracy: 0.4868 - val_loss: 1.2879 - val_accuracy: 0.5444
# Epoch 3/10
# 1563/1563 [==============================] - 110s 71ms/step - loss: 1.0407 - accuracy: 0.6264 - val_loss: 1.0725 - val_accuracy: 0.6360
# Epoch 4/10
# 1563/1563 [==============================] - 105s 67ms/step - loss: 0.8430 - accuracy: 0.7056 - val_loss: 1.1134 - val_accuracy: 0.6159
# Epoch 5/10
# 1563/1563 [==============================] - 110s 71ms/step - loss: 0.6908 - accuracy: 0.7630 - val_loss: 0.8385 - val_accuracy: 0.7133
# Epoch 6/10
# 1563/1563 [==============================] - 110s 70ms/step - loss: 0.5838 - accuracy: 0.8020 - val_loss: 0.6512 - val_accuracy: 0.7841
# Epoch 7/10
# 1563/1563 [==============================] - 110s 70ms/step - loss: 0.4946 - accuracy: 0.8327 - val_loss: 0.6783 - val_accuracy: 0.7820
# Epoch 8/10
# 1563/1563 [==============================] - 110s 70ms/step - loss: 0.4158 - accuracy: 0.8605 - val_loss: 0.5463 - val_accuracy: 0.8174
# Epoch 9/10
# 1563/1563 [==============================] - 110s 70ms/step - loss: 0.3531 - accuracy: 0.8811 - val_loss: 0.6445 - val_accuracy: 0.7994
# Epoch 10/10
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.2946 - accuracy: 0.9010 - val_loss: 0.5701 - val_accuracy: 0.8212

# %%
model4.fit(xtrain,ytrain,validation_data=(xtest,ytest),epochs=10)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 136s 80ms/step - loss: 2.0545 - accuracy: 0.2279 - val_loss: 2.1482 - val_accuracy: 0.2855
# Epoch 2/10
# 1563/1563 [==============================] - 125s 80ms/step - loss: 1.5486 - accuracy: 0.4123 - val_loss: 1.5355 - val_accuracy: 0.4773
# Epoch 3/10
# 1563/1563 [==============================] - 129s 83ms/step - loss: 1.2356 - accuracy: 0.5534 - val_loss: 1.3048 - val_accuracy: 0.5765
# Epoch 4/10
# 1563/1563 [==============================] - 129s 83ms/step - loss: 1.0035 - accuracy: 0.6466 - val_loss: 1.2015 - val_accuracy: 0.5864
# Epoch 5/10
# 1563/1563 [==============================] - 129s 83ms/step - loss: 0.8530 - accuracy: 0.7044 - val_loss: 0.8981 - val_accuracy: 0.6938
# Epoch 6/10
# 1563/1563 [==============================] - 129s 83ms/step - loss: 0.7384 - accuracy: 0.7469 - val_loss: 1.0106 - val_accuracy: 0.6753
# Epoch 7/10
# 1563/1563 [==============================] - 129s 83ms/step - loss: 0.6402 - accuracy: 0.7826 - val_loss: 0.8347 - val_accuracy: 0.7388
# Epoch 8/10
# 1563/1563 [==============================] - 129s 83ms/step - loss: 0.5579 - accuracy: 0.8124 - val_loss: 0.9727 - val_accuracy: 0.7042
# Epoch 9/10
# 1563/1563 [==============================] - 125s 80ms/step - loss: 0.4868 - accuracy: 0.8374 - val_loss: 0.6392 - val_accuracy: 0.7904
# Epoch 10/10
# 1563/1563 [==============================] - 125s 80ms/step - loss: 0.4305 - accuracy: 0.8565 - val_loss: 0.9411 - val_accuracy: 0.7317
