# %%
# !pip install d2l

import math
import pandas as pd
import torch
from torch import nn
from d2l import torch as d2l
# Out:
# Requirement already satisfied: d2l in c:\users\owner\anaconda3\lib\site-packages (1.0.0b0)
# Requirement already satisfied: requests in c:\users\owner\anaconda3\lib\site-packages (from d2l) (2.27.1)
# Requirement already satisfied: matplotlib in c:\users\owner\anaconda3\lib\site-packages (from d2l) (3.5.1)
# Requirement already satisfied: pandas in c:\users\owner\anaconda3\lib\site-packages (from d2l) (1.4.2)
# Requirement already satisfied: numpy in c:\users\owner\anaconda3\lib\site-packages (from d2l) (1.21.5)
# Requirement already satisfied: matplotlib-inline in c:\users\owner\anaconda3\lib\site-packages (from d2l) (0.1.2)
# Requirement already satisfied: jupyter in c:\users\owner\anaconda3\lib\site-packages (from d2l) (1.0.0)
# Requirement already satisfied: gym==0.21.0 in c:\users\owner\anaconda3\lib\site-packages (from d2l) (0.21.0)
# Requirement already satisfied: gpytorch in c:\users\owner\anaconda3\lib\site-packages (from d2l) (1.9.1)
# Requirement already satisfied: scipy in c:\users\owner\anaconda3\lib\site-packages (from d2l) (1.7.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\owner\anaconda3\lib\site-packages (from gym==0.21.0->d2l) (2.0.0)
# Requirement already satisfied: scikit-learn in c:\users\owner\anaconda3\lib\site-packages (from gpytorch->d2l) (1.0.2)
# Requirement already satisfied: linear-operator>=0.2.0 in c:\users\owner\anaconda3\lib\site-packages (from gpytorch->d2l) (0.3.0)
# Requirement already satisfied: torch>=1.11 in c:\users\owner\anaconda3\lib\site-packages (from linear-operator>=0.2.0->gpytorch->d2l) (1.13.0)
# Requirement already satisfied: typing_extensions in c:\users\owner\anaconda3\lib\site-packages (from torch>=1.11->linear-operator>=0.2.0->gpytorch->d2l) (4.1.1)
# Requirement already satisfied: notebook in c:\users\owner\anaconda3\lib\site-packages (from jupyter->d2l) (6.4.8)
# Requirement already satisfied: ipywidgets in c:\users\owner\anaconda3\lib\site-packages (from jupyter->d2l) (7.6.5)
# Requirement already satisfied: ipykernel in c:\users\owner\anaconda3\lib\site-packages (from jupyter->d2l) (6.9.1)
# Requirement already satisfied: nbconvert in c:\users\owner\anaconda3\lib\site-packages (from jupyter->d2l) (6.4.4)
# Requirement already satisfied: jupyter-console in c:\users\owner\anaconda3\lib\site-packages (from jupyter->d2l) (6.4.0)
# Requirement already satisfied: qtconsole in c:\users\owner\anaconda3\lib\site-packages (from jupyter->d2l) (5.3.0)
# Requirement already satisfied: traitlets<6.0,>=5.1.0 in c:\users\owner\anaconda3\lib\site-packages (from ipykernel->jupyter->d2l) (5.1.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\owner\anaconda3\lib\site-packages (from ipykernel->jupyter->d2l) (1.5.1)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\owner\anaconda3\lib\site-packages (from ipykernel->jupyter->d2l) (8.2.0)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\owner\anaconda3\lib\site-packages (from ipykernel->jupyter->d2l) (6.1)
# Requirement already satisfied: nest-asyncio in c:\users\owner\anaconda3\lib\site-packages (from ipykernel->jupyter->d2l) (1.5.5)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\owner\anaconda3\lib\site-packages (from ipykernel->jupyter->d2l) (6.1.12)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\owner\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l) (2.11.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\owner\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l) (0.18.1)
# Requirement already satisfied: backcall in c:\users\owner\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l) (0.2.0)
# Requirement already satisfied: decorator in c:\users\owner\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l) (5.1.1)
# Requirement already satisfied: stack-data in c:\users\owner\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\owner\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l) (0.7.5)
# Requirement already satisfied: colorama in c:\users\owner\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l) (0.4.4)
# Requirement already satisfied: setuptools>=18.5 in c:\users\owner\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l) (61.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\owner\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l) (3.0.20)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\owner\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->d2l) (0.8.3)
# Requirement already satisfied: pyzmq>=13 in c:\users\owner\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->d2l) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\owner\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->d2l) (4.9.2)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\owner\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->d2l) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\owner\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->jupyter->d2l) (302)
# Requirement already satisfied: wcwidth in c:\users\owner\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->jupyter->d2l) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\owner\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel->jupyter->d2l) (1.16.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\owner\anaconda3\lib\site-packages (from ipywidgets->jupyter->d2l) (5.3.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\owner\anaconda3\lib\site-packages (from ipywidgets->jupyter->d2l) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\owner\anaconda3\lib\site-packages (from ipywidgets->jupyter->d2l) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\owner\anaconda3\lib\site-packages (from ipywidgets->jupyter->d2l) (1.0.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\owner\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->d2l) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\owner\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->d2l) (2.15.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\owner\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->d2l) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\owner\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->d2l) (0.18.0)
# Requirement already satisfied: prometheus-client in c:\users\owner\anaconda3\lib\site-packages (from notebook->jupyter->d2l) (0.13.1)
# Requirement already satisfied: argon2-cffi in c:\users\owner\anaconda3\lib\site-packages (from notebook->jupyter->d2l) (21.3.0)
# Requirement already satisfied: jinja2 in c:\users\owner\anaconda3\lib\site-packages (from notebook->jupyter->d2l) (2.11.3)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\owner\anaconda3\lib\site-packages (from notebook->jupyter->d2l) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\owner\anaconda3\lib\site-packages (from notebook->jupyter->d2l) (0.13.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\owner\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->d2l) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\owner\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter->d2l) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\owner\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->d2l) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\owner\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->d2l) (2.21)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\owner\anaconda3\lib\site-packages (from jinja2->notebook->jupyter->d2l) (2.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\owner\anaconda3\lib\site-packages (from matplotlib->d2l) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\owner\anaconda3\lib\site-packages (from matplotlib->d2l) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\owner\anaconda3\lib\site-packages (from matplotlib->d2l) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\owner\anaconda3\lib\site-packages (from matplotlib->d2l) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\owner\anaconda3\lib\site-packages (from matplotlib->d2l) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\owner\anaconda3\lib\site-packages (from matplotlib->d2l) (1.3.2)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\owner\anaconda3\lib\site-packages (from nbconvert->jupyter->d2l) (0.4)
# Requirement already satisfied: bleach in c:\users\owner\anaconda3\lib\site-packages (from nbconvert->jupyter->d2l) (4.1.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\owner\anaconda3\lib\site-packages (from nbconvert->jupyter->d2l) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\owner\anaconda3\lib\site-packages (from nbconvert->jupyter->d2l) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\owner\anaconda3\lib\site-packages (from nbconvert->jupyter->d2l) (0.8.4)
# Requirement already satisfied: testpath in c:\users\owner\anaconda3\lib\site-packages (from nbconvert->jupyter->d2l) (0.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\owner\anaconda3\lib\site-packages (from nbconvert->jupyter->d2l) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\owner\anaconda3\lib\site-packages (from nbconvert->jupyter->d2l) (1.5.0)
# Requirement already satisfied: defusedxml in c:\users\owner\anaconda3\lib\site-packages (from nbconvert->jupyter->d2l) (0.7.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\owner\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->d2l) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\owner\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter->d2l) (0.5.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\owner\anaconda3\lib\site-packages (from pandas->d2l) (2021.3)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\owner\anaconda3\lib\site-packages (from qtconsole->jupyter->d2l) (2.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\owner\anaconda3\lib\site-packages (from requests->d2l) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\owner\anaconda3\lib\site-packages (from requests->d2l) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\owner\anaconda3\lib\site-packages (from requests->d2l) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\owner\anaconda3\lib\site-packages (from requests->d2l) (2021.10.8)
# Requirement already satisfied: joblib>=0.11 in c:\users\owner\anaconda3\lib\site-packages (from scikit-learn->gpytorch->d2l) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\owner\anaconda3\lib\site-packages (from scikit-learn->gpytorch->d2l) (2.2.0)
# Requirement already satisfied: asttokens in c:\users\owner\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->d2l) (2.0.5)
# Requirement already satisfied: executing in c:\users\owner\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->d2l) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\owner\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->d2l) (0.2.2)

# %%
class PositionWiseFFN(nn.Module):  
    """The positionwise feed-forward network."""
    def __init__(self, ffn_num_hiddens, ffn_num_outputs):
        super().__init__()
        self.dense1 = nn.LazyLinear(ffn_num_hiddens)
        self.relu = nn.ReLU()
        self.dense2 = nn.LazyLinear(ffn_num_outputs)

    def forward(self, X):
        return self.dense2(self.relu(self.dense1(X)))
    
    
class AddNorm(nn.Module):  #@save
    """The residual connection followed by layer normalization."""
    def __init__(self, norm_shape, dropout):
        super().__init__()
        self.dropout = nn.Dropout(dropout)
        self.ln = nn.LayerNorm(norm_shape)

    def forward(self, X, Y):
        return self.ln(self.dropout(Y) + X)
    
    
class TransformerEncoderBlock(nn.Module):  
    """The Transformer encoder block."""
    def __init__(self, num_hiddens, ffn_num_hiddens, num_heads, dropout,
                 use_bias=False):
        super().__init__()
        self.attention = d2l.MultiHeadAttention(num_hiddens, num_heads,
                                                dropout, use_bias)
        self.addnorm1 = AddNorm(num_hiddens, dropout)
        self.ffn = PositionWiseFFN(ffn_num_hiddens, num_hiddens)
        self.addnorm2 = AddNorm(num_hiddens, dropout)

    def forward(self, X, valid_lens):
        Y = self.addnorm1(X, self.attention(X, X, X, valid_lens))
        return self.addnorm2(Y, self.ffn(Y))
    

class TransformerEncoder(d2l.Encoder):  
    """The Transformer encoder."""
    def __init__(self, vocab_size, num_hiddens, ffn_num_hiddens,
                 num_heads, num_blks, dropout, use_bias=False):
        super().__init__()
        self.num_hiddens = num_hiddens
        self.embedding = nn.Embedding(vocab_size, num_hiddens)
        self.pos_encoding = d2l.PositionalEncoding(num_hiddens, dropout)
        self.blks = nn.Sequential()
        for i in range(num_blks):
            self.blks.add_module("block"+str(i), TransformerEncoderBlock(
                num_hiddens, ffn_num_hiddens, num_heads, dropout, use_bias))

    def forward(self, X, valid_lens):
        # Since positional encoding values are between -1 and 1, the embedding
        # values are multiplied by the square root of the embedding dimension
        # to rescale before they are summed up
        X = self.pos_encoding(self.embedding(X) * math.sqrt(self.num_hiddens))
        self.attention_weights = [None] * len(self.blks)
        for i, blk in enumerate(self.blks):
            X = blk(X, valid_lens)
            self.attention_weights[
                i] = blk.attention.attention.attention_weights
        return X
    
    
class TransformerDecoderBlock(nn.Module):
    # The i-th block in the Transformer decoder
    def __init__(self, num_hiddens, ffn_num_hiddens, num_heads, dropout, i):
        super().__init__()
        self.i = i
        self.attention1 = d2l.MultiHeadAttention(num_hiddens, num_heads,
                                                 dropout)
        self.addnorm1 = AddNorm(num_hiddens, dropout)
        self.attention2 = d2l.MultiHeadAttention(num_hiddens, num_heads,
                                                 dropout)
        self.addnorm2 = AddNorm(num_hiddens, dropout)
        self.ffn = PositionWiseFFN(ffn_num_hiddens, num_hiddens)
        self.addnorm3 = AddNorm(num_hiddens, dropout)

    def forward(self, X, state):
        enc_outputs, enc_valid_lens = state[0], state[1]
        # During training, all the tokens of any output sequence are processed
        # at the same time, so state[2][self.i] is None as initialized. When
        # decoding any output sequence token by token during prediction,
        # state[2][self.i] contains representations of the decoded output at
        # the i-th block up to the current time step
        if state[2][self.i] is None:
            key_values = X
        else:
            key_values = torch.cat((state[2][self.i], X), dim=1)
        state[2][self.i] = key_values
        if self.training:
            batch_size, num_steps, _ = X.shape
            # Shape of dec_valid_lens: (batch_size, num_steps), where every
            # row is [1, 2, ..., num_steps]
            dec_valid_lens = torch.arange(
                1, num_steps + 1, device=X.device).repeat(batch_size, 1)
        else:
            dec_valid_lens = None
        # Self-attention
        X2 = self.attention1(X, key_values, key_values, dec_valid_lens)
        Y = self.addnorm1(X, X2)
        # Encoder-decoder attention. Shape of enc_outputs:
        # (batch_size, num_steps, num_hiddens)
        Y2 = self.attention2(Y, enc_outputs, enc_outputs, enc_valid_lens)
        Z = self.addnorm2(Y, Y2)
        return self.addnorm3(Z, self.ffn(Z)), state
    
    
class TransformerDecoder(d2l.AttentionDecoder):
    def __init__(self, vocab_size, num_hiddens, ffn_num_hiddens, num_heads,
                 num_blks, dropout):
        super().__init__()
        self.num_hiddens = num_hiddens
        self.num_blks = num_blks
        self.embedding = nn.Embedding(vocab_size, num_hiddens)
        self.pos_encoding = d2l.PositionalEncoding(num_hiddens, dropout)
        self.blks = nn.Sequential()
        for i in range(num_blks):
            self.blks.add_module("block"+str(i), TransformerDecoderBlock(
                num_hiddens, ffn_num_hiddens, num_heads, dropout, i))
        self.dense = nn.LazyLinear(vocab_size)

    def init_state(self, enc_outputs, enc_valid_lens):
        return [enc_outputs, enc_valid_lens, [None] * self.num_blks]

    def forward(self, X, state):
        X = self.pos_encoding(self.embedding(X) * math.sqrt(self.num_hiddens))
        self._attention_weights = [[None] * len(self.blks) for _ in range (2)]
        for i, blk in enumerate(self.blks):
            X, state = blk(X, state)
            # Decoder self-attention weights
            self._attention_weights[0][
                i] = blk.attention1.attention.attention_weights
            # Encoder-decoder attention weights
            self._attention_weights[1][
                i] = blk.attention2.attention.attention_weights
        return self.dense(X), state

    @property
    def attention_weights(self):
        return self._attention_weights

# %%
data = d2l.MTFraEng(batch_size=128)
num_hiddens, num_blks, dropout = 256, 4, 0.2
ffn_num_hiddens, num_heads = 128,8
encoder = TransformerEncoder(
    len(data.src_vocab), num_hiddens, ffn_num_hiddens, num_heads,
    num_blks, dropout)
decoder = TransformerDecoder(
    len(data.tgt_vocab), num_hiddens, ffn_num_hiddens, num_heads,
    num_blks, dropout)
model = d2l.Seq2Seq(encoder, decoder, tgt_pad=data.tgt_vocab['<pad>'],
                    lr=0.0015)
trainer = d2l.Trainer(max_epochs=50, gradient_clip_val=1, num_gpus=1)
trainer.fit(model, data)

# %%
engs = ['go .', 'i lost .', 'he\'s calm .', 'i\'m home .']
fras = ['va !', 'j\'ai perdu .', 'il est calme .', 'je suis chez moi .']
preds, _ = model.predict_step(
    data.build(engs, fras), d2l.try_gpu(), data.num_steps)
for en, fr, p in zip(engs, fras, preds):
    translation = []
    for token in data.tgt_vocab.to_tokens(p):
        if token == '<eos>':
            break
        translation.append(token)
    print(f'{en} => {translation}, bleu,'
          f'{d2l.bleu(" ".join(translation), fr, k=2):.3f}')
# Out:
# go . => ['va', '!'], bleu,1.000
# i lost . => ["j'ai", 'perdu', '.'], bleu,1.000
# he's calm . => ['<unk>', '.'], bleu,0.000
# i'm home . => ['je', 'suis', 'chez', 'moi', '.'], bleu,1.000
